# %%
from Chapter2_part2 import isEvenNumber # không import được \ cần chuyển sang .py

n = int(input("Nhập vào một số để kiểm tra: "))
if isEvenNumber(n):
    print("Là số chẵn")
else:
    print("Là số lẻ")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 5
#       2 sys.path.append(r"C:\Users\ACER\python_workspace\Lab")
#       4 import nbimporter
# ----> 5 from Chapter2_part2 import isEvenNumber
#       7 n = int(input("Nhập vào một số để kiểm tra: "))
#       8 if isEvenNumber(n):
#
# ModuleNotFoundError: No module named 'Chapter2_part2'
